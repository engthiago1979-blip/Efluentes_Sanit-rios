# %%
# =============================================================================
# Autor:   Thiago Souza (@engthiago1979-blip)
# Criado:  19-04-2026
# Uso:     Estatística avançada (MK, KW, Descritiva), P95 e plots para todo o escopo CONAMA 430.
# =============================================================================

import os
import pandas as pd
import numpy as np
import scipy.stats as stats
import pymannkendall as mk
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings

# Ignora warnings de divisão por zero do numpy/scipy em séries sem variância
warnings.filterwarnings("ignore")

# --- 1. CONFIGURAÇÕES ---
DIR_BASE = r"C:\Users\thiago\Documents\estudos_python\etes_nesa\base_dados"
DIR_PRODUTOS = r"C:\Users\thiago\Documents\estudos_python\etes_nesa\Efluentes_Sanitários\produtos"
FILE_INPUT = os.path.join(DIR_BASE, "ETEs_NorteEnergia_Processado_v1.xlsx")

os.makedirs(DIR_PRODUTOS, exist_ok=True)

NESA_COLORS = {'primary': '#009CA7', 'vmp': '#F25A3C', 'text': '#404041', 'highlight': '#B9F8FF'}
plt.rcParams['font.family'] = 'Segoe UI'

# --- 2. VMPs CONAMA 430/11 (Art. 16) ---
VMP_CONAMA = {
    'DEMANDA_BIOQUIMICA_DE_OXIGENIO': 120.0,
    'PH': (5.0, 9.0),
    'TEMPERATURA_DO_EFLUENTE': 40.0,
    'MATERIAIS_SEDIMENTAVEIS': 1.0,
    'OLEOS_E_GRAXAS': 50.0,
    'ARSENIO_TOTAL': 0.5,
    'CADMIO_TOTAL': 0.2,
    'CHUMBO_TOTAL': 0.5,
    'CIANETO_TOTAL': 1.0,
    'CROMO_HEXAVALENTE': 0.1,
    'CROMO_TRIVALENTE': 1.0,
    'FERRO_DISSOLVIDO': 15.0,
    'MANGANES_DISSOLVIDO': 1.0,
    'MERCURIO_TOTAL': 0.01,
    'SULFETO_TOTAL': 1.0,
    'BENZENO': 1.2,
    'CLOROFORMIO': 1.0,
    'ETILBENZENO': 1.4,
    'FENOIS_TOTAIS': 0.5,
    'TETRACLORETO_DE_CARBONO': 1.0,
    'TRICLOROETENO': 1.0,
    'TOLUENO': 1.2,
    'XILENO_TOTAL': 1.6
}

# --- 3. MOTORES ESTATÍSTICOS ---
def analisar_parametro(df, parametro, limite_conama, col_ete):
    """Calcula Descritiva, Auditoria P95 e Tendência de Mann-Kendall."""
    resultados = []
    
    for ete in df[col_ete].dropna().unique():
        df_ete = df[df[col_ete] == ete].sort_values('DATA')
        serie = df_ete[parametro].dropna()
        
        if len(serie) < 3: 
            continue
            
        # 3.1 Estatística Descritiva Básica
        media = serie.mean()
        desvio = serie.std()
        minimo = serie.min()
        maximo = serie.max()
        p95 = np.percentile(serie, 95)
        
        # 3.2 Conformidade e P95
        if isinstance(limite_conama, tuple):
            vmin, vmax = limite_conama
            amostras_ok = len(serie[(serie >= vmin) & (serie <= vmax)])
            status_auditoria = "ROBUSTO" if (serie.min() >= vmin and p95 <= vmax) else "RISCO"
            limite_str = f"{vmin} a {vmax}"
        else:
            amostras_ok = len(serie[serie <= limite_conama])
            status_auditoria = "ROBUSTO" if p95 <= limite_conama else "RISCO"
            limite_str = str(limite_conama)
            
        taxa_conformidade = (amostras_ok / len(serie)) * 100
        
        # 3.3 Teste de Tendência (Mann-Kendall)
        # Proteção contra série sem variância (ex: só valores <LQ)
        if desvio > 0 and len(serie) >= 4:
            try:
                mk_res = mk.original_test(serie)
                tendencia = mk_res.trend # 'increasing', 'decreasing', 'no trend'
                p_val_mk = mk_res.p
                # Tradução
                if tendencia == 'increasing': tendencia = 'Crescente (Piora)'
                elif tendencia == 'decreasing': tendencia = 'Decrescente (Melhora)'
                else: tendencia = 'Estável'
            except:
                tendencia, p_val_mk = "Erro Cálculo", np.nan
        else:
            tendencia, p_val_mk = "Sem variância/dados", np.nan

        resultados.append({
            'Parâmetro': parametro.replace('_', ' '),
            'ETE': ete, 
            'N': len(serie),
            'Mínimo': round(minimo, 3),
            'Média': round(media, 3),
            'Máximo': round(maximo, 3),
            'Desvio Padrão': round(desvio, 3),
            'P95 (Auditoria)': round(p95, 3),
            'VMP CONAMA': limite_str,
            'Conformidade (%)': f"{taxa_conformidade:.1f}%",
            'Avaliação': status_auditoria,
            'Tendência (MK)': tendencia,
            'p-value (MK)': round(p_val_mk, 4) if pd.notna(p_val_mk) else "N/A"
        })
        
    return resultados

def teste_kruskal_wallis_geral(df, parametro, col_ete):
    """Verifica se há diferença significativa de desempenho entre as ETEs."""
    grupos = []
    nomes_etes = []
    
    for ete in df[col_ete].dropna().unique():
        serie = df[df[col_ete] == ete][parametro].dropna()
        if len(serie) >= 3 and serie.std() > 0:
            grupos.append(serie)
            nomes_etes.append(ete)
            
    if len(grupos) > 1:
        stat, p_val = stats.kruskal(*grupos)
        significativo = "SIM" if p_val < 0.05 else "NÃO"
        return {
            'Parâmetro': parametro.replace('_', ' '),
            'ETEs Comparadas': " vs ".join(nomes_etes),
            'Estatística (H)': round(stat, 3),
            'p-value (KW)': round(p_val, 4),
            'Diferença Significativa?': significativo
        }
    return None

def plotar_matplotlib_v4(df, parametro, ete, col_ete, dir_out):
    """Plot estático de Alta Resolução (Matplotlib)."""
    df_plot = df[df[col_ete] == ete].sort_values('DATA').dropna(subset=[parametro])
    if len(df_plot) < 2: return
    
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(df_plot['DATA'], df_plot[parametro], marker='o', linestyle='-', 
            color=NESA_COLORS['primary'], linewidth=2)
    
    limite = VMP_CONAMA[parametro]
    if isinstance(limite, tuple):
        ax.axhline(y=limite[0], color=NESA_COLORS['vmp'], linestyle='--', linewidth=1.5)
        ax.axhline(y=limite[1], color=NESA_COLORS['vmp'], linestyle='--', linewidth=1.5, label=f"CONAMA ({limite[0]} a {limite[1]})")
    else:
        ax.axhline(y=limite, color=NESA_COLORS['vmp'], linestyle='--', linewidth=1.5, label=f"VMP ({limite})")
    
    # Banda de P95 para auditoria visual
    p95 = np.percentile(df_plot[parametro], 95)
    ax.axhline(y=p95, color=NESA_COLORS['highlight'], linestyle='-.', linewidth=2, label=f"P95 ({p95:.2f})")
    
    ax.set_title(f"{parametro.replace('_', ' ')}\nETE: {ete}", fontsize=12, color=NESA_COLORS['text'], loc='left')
    ax.set_ylabel("Concentração (mg/L)", fontsize=10)
    
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m/%Y'))
    plt.xticks(rotation=45)
    ax.grid(True, axis='y', linestyle=':', alpha=0.5)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.legend(frameon=False, loc='best', fontsize=9)
    
    nome_arquivo = f"Plot_{parametro}_{ete.replace(' ', '_')}.png"
    plt.savefig(os.path.join(dir_out, nome_arquivo), dpi=600, bbox_inches='tight')
    plt.close()

# --- 4. EXECUÇÃO DO PIPELINE ---
if __name__ == "__main__":
    try:
        df = pd.read_excel(FILE_INPUT)
        col_ete = [c for c in df.columns if 'DESCRICAO' in c.upper() and 'PONTO' in c.upper()][0]

        # Correção de ruídos (Obrigatório)
        df[col_ete] = df[col_ete].astype(str).str.upper().str.strip()
        df[col_ete] = df[col_ete].replace({'ETE 1': 'ETE 01', 'ETE 2': 'ETE 02'})

        relatorio_geral = []
        relatorio_kw = []

        print("[*] Iniciando processamento estatístico completo...")
        
        for param in VMP_CONAMA.keys():
            if param in df.columns:
                print(f"    -> Analisando: {param}")
                
                # 1. Estatística Básica, MK e P95
                resultados_descritiva = analisar_parametro(df, param, VMP_CONAMA[param], col_ete)
                if resultados_descritiva:
                    relatorio_geral.extend(resultados_descritiva)
                
                # 2. Teste de Hipótese (Kruskal-Wallis)
                resultado_kw = teste_kruskal_wallis_geral(df, param, col_ete)
                if resultado_kw:
                    relatorio_kw.append(resultado_kw)
                
                # 3. Geração Gráfica
                for ete in df[col_ete].unique():
                    plotar_matplotlib_v4(df, param, ete, col_ete, DIR_PRODUTOS)

        # Exportação Multi-Aba
        df_final = pd.DataFrame(relatorio_geral)
        df_kw = pd.DataFrame(relatorio_kw)
        
        caminho_excel = os.path.join(DIR_PRODUTOS, "Relatorio_Analitico_Mestre.xlsx")
        with pd.ExcelWriter(caminho_excel, engine='openpyxl') as writer:
            df_final.to_excel(writer, sheet_name="Estatistica_e_Tendencia", index=False)
            if not df_kw.empty:
                df_kw.to_excel(writer, sheet_name="Comparativo_Kruskal_Wallis", index=False)

        print(f"\n[+] SUCESSO! Relatório Mestre com todas as estatísticas salvo em: {caminho_excel}")
        
    except Exception as e:
        print(f"[!] Erro crítico: {e}")
# Out:
# [*] Iniciando processamento estatístico completo...
#     -> Analisando: DEMANDA_BIOQUIMICA_DE_OXIGENIO
#     -> Analisando: PH
#     -> Analisando: TEMPERATURA_DO_EFLUENTE
#     -> Analisando: MATERIAIS_SEDIMENTAVEIS
#     -> Analisando: OLEOS_E_GRAXAS
#     -> Analisando: ARSENIO_TOTAL
#     -> Analisando: CADMIO_TOTAL
#     -> Analisando: CHUMBO_TOTAL
#     -> Analisando: CIANETO_TOTAL
#     -> Analisando: CROMO_HEXAVALENTE
#     -> Analisando: CROMO_TRIVALENTE
#     -> Analisando: FERRO_DISSOLVIDO
#     -> Analisando: MANGANES_DISSOLVIDO
#     -> Analisando: MERCURIO_TOTAL
#     -> Analisando: SULFETO_TOTAL
#     -> Analisando: BENZENO
#     -> Analisando: CLOROFORMIO
#     -> Analisando: ETILBENZENO
#     -> Analisando: FENOIS_TOTAIS
#     -> Analisando: TETRACLORETO_DE_CARBONO
#     -> Analisando: TRICLOROETENO
#     -> Analisando: TOLUENO
#     -> Analisando: XILENO_TOTAL
#
# ...

# %%
# =============================================================================
# Autor:   Thiago Souza (@engthiago1979-blip)
# Criado:  19-04-2026
# Uso:     Módulo QA/QC: Gera tabela e mapa de calor quantificando os dados 
#          censurados (<LQ) por Parâmetro e por ETE.
# =============================================================================

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. CONFIGURAÇÕES ---
DIR_BASE = r"C:\Users\thiago\Documents\estudos_python\etes_nesa\base_dados"
DIR_PRODUTOS = r"C:\Users\thiago\Documents\estudos_python\etes_nesa\Efluentes_Sanitários\produtos"
FILE_INPUT = os.path.join(DIR_BASE, "ETEs_NorteEnergia_Processado_v1.xlsx")

NESA_COLORS = {'primary': '#009CA7', 'text': '#404041'}
plt.rcParams['font.family'] = 'Segoe UI'

# --- 2. EXECUÇÃO ---
try:
    print("[*] Lendo a base de dados processada para auditoria de QA/QC...")
    df = pd.read_excel(FILE_INPUT)
    
    # Identificar a coluna da ETE dinamicamente e corrigir ruídos
    col_ete = [c for c in df.columns if 'DESCRICAO' in c.upper() and 'PONTO' in c.upper()][0]
    df[col_ete] = df[col_ete].astype(str).str.upper().str.strip()
    df[col_ete] = df[col_ete].replace({'ETE 1': 'ETE 01', 'ETE 2': 'ETE 02'})

    # Separar as colunas (Metadados vs Parâmetros analíticos)
    colunas_metadados = df.columns[:4].tolist()
    parametros = [c for c in df.columns if c not in colunas_metadados and not c.endswith('_IMPUTADO_LQ') and not c.endswith('_STATUS_VMP')]

    dados_qc = []

    print("[*] Contabilizando matriz de dados censurados...")
    for param in parametros:
        col_flag = param + "_IMPUTADO_LQ"
        has_flag = col_flag in df.columns

        for ete in df[col_ete].unique():
            df_ete = df[df[col_ete] == ete]
            serie_param = df_ete[param].dropna()
            n_total = len(serie_param)

            if n_total > 0:
                if has_flag:
                    # Conta os 'True' na coluna flag, apenas onde o parâmetro possui dado preenchido
                    n_censurado = df_ete.loc[serie_param.index, col_flag].fillna(False).sum()
                else:
                    n_censurado = 0

                perc_censurado = (n_censurado / n_total) * 100

                dados_qc.append({
                    'ETE': ete,
                    'Parâmetro': param.replace('_', ' '),
                    'Total de Amostras (N)': int(n_total),
                    'Dados Censurados (<LQ)': int(n_censurado),
                    '% Censurado': round(perc_censurado, 1)
                })

    # Criando o DataFrame Final
    df_qc = pd.DataFrame(dados_qc)
    
    # 1. Exportando a Tabela
    caminho_excel = os.path.join(DIR_PRODUTOS, "Relatorio_QAQC_Dados_Censurados.xlsx")
    df_qc.to_excel(caminho_excel, index=False)
    
    # 2. Gerando o Mapa de Calor (Heatmap)
    # Filtramos apenas os parâmetros que tiveram dados censurados para o gráfico não ficar gigante e vazio
    df_qc_filtrado = df_qc[df_qc['% Censurado'] > 0]
    
    if not df_qc_filtrado.empty:
        pivot_qc = df_qc_filtrado.pivot(index='Parâmetro', columns='ETE', values='% Censurado').fillna(0)
        
        plt.figure(figsize=(10, max(6, len(pivot_qc) * 0.4))) # Altura dinâmica baseada na qtd de parâmetros
        ax = sns.heatmap(pivot_qc, annot=True, fmt=".1f", cmap="GnBu", linewidths=1, 
                         cbar_kws={'label': '% de Amostras Censuradas (<LQ)'})
        
        plt.title("Mapa de Calor (QA/QC): Incidência de Dados Censurados por ETE", 
                  fontsize=14, color=NESA_COLORS['text'], pad=20)
        plt.ylabel("Parâmetro Analítico", fontsize=11, fontweight='bold', color=NESA_COLORS['text'])
        plt.xlabel("Estação de Tratamento (ETE)", fontsize=11, fontweight='bold', color=NESA_COLORS['text'])
        
        caminho_fig = os.path.join(DIR_PRODUTOS, "Heatmap_QAQC_Censurados.png")
        plt.savefig(caminho_fig, dpi=300, bbox_inches='tight')
        plt.close()

    print(f"\n[+] SUCESSO! Produtos gerados em: {DIR_PRODUTOS}")
    print("  -> Tabela: Relatorio_QAQC_Dados_Censurados.xlsx")
    if not df_qc_filtrado.empty:
        print("  -> Gráfico: Heatmap_QAQC_Censurados.png")

    print("\n=== TOP 10 MAIORES INCIDÊNCIAS DE CENSURA (<LQ) ===")
    top_10 = df_qc.sort_values(by='% Censurado', ascending=False).head(10)
    print(top_10.to_string(index=False))

except Exception as e:
    print(f"[!] Erro no processamento de QA/QC: {e}")
# Out:
# [*] Lendo a base de dados processada para auditoria de QA/QC...
# [*] Contabilizando matriz de dados censurados...
#
# [+] SUCESSO! Produtos gerados em: C:\Users\thiago\Documents\estudos_python\etes_nesa\Efluentes_Sanitários\produtos
#   -> Tabela: Relatorio_QAQC_Dados_Censurados.xlsx
#   -> Gráfico: Heatmap_QAQC_Censurados.png
#
# === TOP 10 MAIORES INCIDÊNCIAS DE CENSURA (<LQ) ===
#          ETE                                Parâmetro  Total de Amostras (N)  Dados Censurados (<LQ)  % Censurado
#       ETE 01                            ARSENIO TOTAL                     26                      26        100.0
#       ETE PM                            ARSENIO TOTAL                     20                      20        100.0
# ETE COMPACTA                         CROMO TRIVALENTE                     24                      24        100.0
#       ETE PM                         CROMO TRIVALENTE                     20                      20        100.0
# ...

# %%
# =============================================================================
# Autor:   Thiago Souza (@engthiago1979-blip)
# Criado:  01-05-2026
# Uso:     Versão 8.0 (Dossiê Visual Definitivo - Segregado por UHE).
#          - Escala do Eixo X fixada de Jan/2024 a Mar/2026.
#          - Segregação completa: Gráficos e cálculos independentes para Belo Monte e Pimental.
#          - Tratamento de 'NaNs' para garantir rótulos limpos mesmo com meses pendentes.
# =============================================================================

import os
import re
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# --- 1. CONFIGURAÇÕES E PASTAS ---
DIR_BASE = r"C:\Users\thiago\Documents\estudos_python\etes_nesa\base_dados"
DIR_PRODUTOS = r"C:\Users\thiago\Documents\estudos_python\etes_nesa\Efluentes_Sanitários\produtos"
FILE_VAZAO = os.path.join(DIR_BASE, "vazão turbinada.xlsx")
os.makedirs(DIR_PRODUTOS, exist_ok=True)

# Paleta Norte Energia
NESA_COLORS = {
    'rio': '#B9F8FF', 'ete_barras': '#009CA7', 'linha_vmp': '#F25A3C', 
    'dbo': '#009CA7', 'nh3': '#52BD8B', 'fosforo': '#FEBD2A', 'lab': '#404041'
}
plt.rcParams['font.family'] = 'Segoe UI'

# --- 2. MOTOR DE TEMPO (BLINDADO) ---
def extrair_data_segura(val):
    if pd.isna(val): return pd.NaT
    if isinstance(val, (pd.Timestamp, datetime.datetime)):
        return pd.Timestamp(year=val.year, month=val.month, day=1)
    s = str(val).lower()
    meses_pt = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
    for i, mes in enumerate(meses_pt):
        if mes in s:
            anos = re.findall(r'\d{2,4}', s)
            if anos:
                ano = int(anos[-1])
                if ano < 100: ano += 2000
                return pd.Timestamp(year=ano, month=i+1, day=1)
    return pd.NaT

# --- 3. DADOS DE LANÇAMENTO (Atualizado até Mar/26) ---
dados_gri = {
    'ETE_01': [651.4, 635.7, 503.4, 675.4, 639.4, 569.0, 566.6, 547.0, 455.1, 679.9, 581.8, 551.6, 324.8, 169.6, 99.2, 155.2, 129.6, 110.4, 137.6, 120.0, 146.4, 160.0, 144.8, 92.0, 107.2, 111.2, 145.6],
    'ETE_02': [597.4, 525.1, 415.0, 535.8, 579.8, 469.4, 534.2, 438.6, 330.9, 581.3, 405.8, 387.2, 2414.4, 1060.8, 959.2, 1325.6, 1130.4, 640.8, 885.6, 580.0, 664.8, 688.0, 585.6, 648.8, 602.4, 502.4, 623.76],
    'ETE_PM': [87.0, 198.4, 206.1, 185.6, 215.0, 245.1, 294.4, 258.4, 291.0, 338.5, 308.6, 314.5, 281.6, 146.4, 133.76, 137.92, 142.56, 141.12, 126.72, 104.16, 104.48, 0.0, 109.92, 0.0, 0.0, 57.6, 65.92],
    'ETE_COMPACTA': [21.8, 49.6, 51.5, 46.4, 50.6, 52.5, 52.8, 52.0, 45.4, 52.3, 46.2, 46.7, 41.6, 16.0, 18.24, 22.08, 23.04, 20.48, 18.88, 15.84, 19.76, 25.12, 19.68, 19.04, 14.72, 14.4, 16.48]
}
df_gri = pd.DataFrame(dados_gri)
df_gri['DATA_DT'] = pd.date_range(start='2024-01-01', periods=len(df_gri), freq='MS')

P95_DBO = 88.78
P95_NH3 = 45.0   
P95_FOSF = 4.5   

LIMITE_INICIO = pd.Timestamp('2023-12-15')
LIMITE_FIM = pd.Timestamp('2026-03-15')

try:
    # Lendo a vazão
    df_vazao = pd.read_excel(FILE_VAZAO)
    df_vazao.columns = ['Mes_Original', 'Q_Pimental_m3s', 'Q_BeloMonte_m3s']
    df_vazao = df_vazao.dropna(subset=['Mes_Original'])
    df_vazao['DATA_DT'] = df_vazao['Mes_Original'].apply(extrair_data_segura)
    df_vazao = df_vazao.dropna(subset=['DATA_DT'])

    # CRUZAMENTO (Left Join garante que a linha do tempo vá até Mar/26 sempre)
    df_final = pd.merge(df_gri, df_vazao, on='DATA_DT', how='left')
    
    # =========================================================================
    # BALANÇO DE MASSA - BELO MONTE (ETE 01 + ETE 02)
    # =========================================================================
    df_final['Vol_Rio_BM_m3mes'] = df_final['Q_BeloMonte_m3s'] * 86400 * 30.44
    df_final['Vol_Efluente_BM'] = df_final['ETE_01'] + df_final['ETE_02']

    df_final['Fator_Diluicao_BM'] = df_final['Vol_Rio_BM_m3mes'] / df_final['Vol_Efluente_BM']
    df_final['Adicao_DBO_BM_mgL'] = (df_final['Vol_Efluente_BM'] * P95_DBO) / df_final['Vol_Rio_BM_m3mes']
    df_final['Adicao_NH3_BM_mgL'] = (df_final['Vol_Efluente_BM'] * P95_NH3) / df_final['Vol_Rio_BM_m3mes']
    df_final['Adicao_FOSF_BM_mgL'] = (df_final['Vol_Efluente_BM'] * P95_FOSF) / df_final['Vol_Rio_BM_m3mes']

    # =========================================================================
    # BALANÇO DE MASSA - PIMENTAL (ETE PM + COMPACTA)
    # =========================================================================
    df_final['Vol_Rio_PM_m3mes'] = df_final['Q_Pimental_m3s'] * 86400 * 30.44
    df_final['Vol_Efluente_PM'] = df_final['ETE_PM'] + df_final['ETE_COMPACTA']

    df_final['Fator_Diluicao_PM'] = df_final['Vol_Rio_PM_m3mes'] / df_final['Vol_Efluente_PM']
    df_final['Adicao_DBO_PM_mgL'] = (df_final['Vol_Efluente_PM'] * P95_DBO) / df_final['Vol_Rio_PM_m3mes']
    df_final['Adicao_NH3_PM_mgL'] = (df_final['Vol_Efluente_PM'] * P95_NH3) / df_final['Vol_Rio_PM_m3mes']
    df_final['Adicao_FOSF_PM_mgL'] = (df_final['Vol_Efluente_PM'] * P95_FOSF) / df_final['Vol_Rio_PM_m3mes']

    print("\n" + "="*80)
    print("  DOSSIÊ VISUAL SEGREGADO POR UHE (Versão 8.0 - Jan/24 a Mar/26)")
    print("="*80)

    # =========================================================================
    # FUNÇÕES GERADORAS DE GRÁFICOS (Para reaproveitamento BM e PM)
    # =========================================================================
    def gerar_grafico_diluicao(fator_col, uhe_nome, arquivo_nome):
        fig, ax = plt.subplots(figsize=(14, 6))
        fator_milhoes = df_final[fator_col] / 1e6
        
        bars = ax.bar(df_final['DATA_DT'], fator_milhoes, width=22, color=NESA_COLORS['ete_barras'], alpha=0.9, label='Fator Mensal Apurado')
        
        # Tratamento para não exibir "nan" se o mês ainda não tiver dados de vazão
        labels = [f'{v:.1f}' if pd.notna(v) else '' for v in fator_milhoes]
        ax.bar_label(bars, labels=labels, padding=5, fontsize=9, color='#404041', fontweight='bold')
        
        ax.set_ylim(0, fator_milhoes.max() * 1.15 if pd.notna(fator_milhoes.max()) else 10)
        ax.set_xlim(LIMITE_INICIO, LIMITE_FIM)
        
        ax.set_title(f"Proporção Hidrodinâmica UHE {uhe_nome}: Rio Xingu vs Efluente Sanitário", fontsize=14, fontweight='bold', color='#404041')
        ax.set_ylabel("Milhões de Litros de Rio p/ 1L de Efluente", fontsize=11, fontweight='bold')
        
        min_fator = fator_milhoes.min()
        if pd.notna(min_fator):
            ax.axhline(min_fator, color=NESA_COLORS['linha_vmp'], linestyle='--', linewidth=2.5, 
                        label=f'Pior Cenário Histórico (1 p/ {min_fator:.1f} M)')
        
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b/%Y'))
        ax.grid(axis='y', linestyle='--', alpha=0.4)
        ax.legend(loc='upper left', frameon=True, facecolor='white')
        plt.xticks(rotation=45)
        fig.tight_layout()
        
        fig.savefig(os.path.join(DIR_PRODUTOS, arquivo_nome), dpi=600)
        plt.show()
        plt.close(fig)

    def gerar_grafico_impacto(param_col, cor, nome_parametro, limite_lab, nota_conama, limite_y, uhe_nome, arquivo_nome):
        fig, ax = plt.subplots(figsize=(12, 5))
        
        ax.plot(df_final['DATA_DT'], df_final[param_col], color=cor, linewidth=3, label=f'Adição Efetiva de {nome_parametro}')
        
        # O fill_between ignora NaNs, então é seguro
        mask = df_final[param_col].notna()
        ax.fill_between(df_final['DATA_DT'][mask], 0, df_final[param_col][mask], color=cor, alpha=0.2)

        ax.axhline(limite_lab, color=NESA_COLORS['lab'], linestyle='-', linewidth=2, label=f'Limite de Detecção Lab. ({limite_lab} mg/L)')

        ax.set_ylim(0, limite_y)
        ax.set_xlim(LIMITE_INICIO, LIMITE_FIM)

        ax.annotate(nota_conama, 
                    xy=(pd.Timestamp('2025-01-01'), limite_y * 0.95), 
                    xytext=(pd.Timestamp('2025-01-01'), limite_y * 0.85),
                    color=NESA_COLORS['linha_vmp'], fontweight='bold', fontsize=11, ha='center',
                    arrowprops=dict(facecolor=NESA_COLORS['linha_vmp'], arrowstyle='->', lw=2))

        ax.set_title(f"Modelagem de Risco UHE {uhe_nome}: Impacto de {nome_parametro}", fontsize=14, fontweight='bold', color='#404041')
        ax.set_ylabel("Concentração Adicionada (mg/L)", fontsize=11, fontweight='bold')
        
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b/%Y'))
        ax.grid(axis='y', linestyle=':', alpha=0.5)
        ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)
        plt.xticks(rotation=45)
        
        fig.savefig(os.path.join(DIR_PRODUTOS, arquivo_nome), dpi=600, bbox_inches='tight')
        plt.show()
        plt.close(fig)

    # =========================================================================
    # GERAÇÃO DOS GRÁFICOS: BELO MONTE
    # =========================================================================
    print("[*] Gerando pacote de gráficos para UHE Belo Monte...")
    gerar_grafico_diluicao('Fator_Diluicao_BM', 'Belo Monte', "Produto1A_Diluicao_BeloMonte.png")
    gerar_grafico_impacto('Adicao_DBO_BM_mgL', NESA_COLORS['dbo'], 'DBO', 2.0, 'Limite CONAMA (120 mg/L) -> Fora de Escala', 2.5, 'Belo Monte', "Produto2A_Impacto_DBO_BM.png")
    gerar_grafico_impacto('Adicao_NH3_BM_mgL', NESA_COLORS['nh3'], 'N. Amoniacal', 0.5, 'Limite CONAMA (20 mg/L) -> Fora de Escala\n*Isento pelo Art. 21', 0.7, 'Belo Monte', "Produto3A_Impacto_NH3_BM.png")
    gerar_grafico_impacto('Adicao_FOSF_BM_mgL', NESA_COLORS['fosforo'], 'Fósforo Total', 0.5, 'Risco de Eutrofização -> Fora de Escala', 0.7, 'Belo Monte', "Produto4A_Impacto_Fosforo_BM.png")

    # =========================================================================
    # GERAÇÃO DOS GRÁFICOS: PIMENTAL
    # =========================================================================
    print("[*] Gerando pacote de gráficos para UHE Pimental...")
    gerar_grafico_diluicao('Fator_Diluicao_PM', 'Pimental (TVR)', "Produto1B_Diluicao_Pimental.png")
    gerar_grafico_impacto('Adicao_DBO_PM_mgL', NESA_COLORS['dbo'], 'DBO', 2.0, 'Limite CONAMA (120 mg/L) -> Fora de Escala', 2.5, 'Pimental', "Produto2B_Impacto_DBO_PM.png")
    gerar_grafico_impacto('Adicao_NH3_PM_mgL', NESA_COLORS['nh3'], 'N. Amoniacal', 0.5, 'Limite CONAMA (20 mg/L) -> Fora de Escala\n*Isento pelo Art. 21', 0.7, 'Pimental', "Produto3B_Impacto_NH3_PM.png")
    gerar_grafico_impacto('Adicao_FOSF_PM_mgL', NESA_COLORS['fosforo'], 'Fósforo Total', 0.5, 'Risco de Eutrofização -> Fora de Escala', 0.7, 'Pimental', "Produto4B_Impacto_Fosforo_PM.png")

    # =========================================================================
    # PLANILHA DE EXPORTAÇÃO MESTRA
    # =========================================================================
    df_final['Mês/Ano'] = df_final['DATA_DT'].dt.strftime('%m/%Y')
    
    colunas_export = [
        'Mês/Ano', 
        'Q_BeloMonte_m3s', 'Vol_Rio_BM_m3mes', 'Vol_Efluente_BM', 'Fator_Diluicao_BM', 'Adicao_DBO_BM_mgL', 'Adicao_NH3_BM_mgL', 'Adicao_FOSF_BM_mgL',
        'Q_Pimental_m3s', 'Vol_Rio_PM_m3mes', 'Vol_Efluente_PM', 'Fator_Diluicao_PM', 'Adicao_DBO_PM_mgL', 'Adicao_NH3_PM_mgL', 'Adicao_FOSF_PM_mgL'
    ]
    
    df_final[colunas_export].to_excel(os.path.join(DIR_PRODUTOS, "Relatorio_Diluicao_Mestre_Segregado.xlsx"), index=False)

    print(f"\n[*] Concluído! 8 Gráficos segregados foram exibidos na tela e salvos na pasta 'produtos'.")

except Exception as e:
    print(f"\n[!] ERRO CRÍTICO ENCONTRADO: {e}")
# Out:
# ...
#   DOSSIÊ VISUAL SEGREGADO POR UHE (Versão 8.0 - Jan/24 a Mar/26)
# ...
# [*] Gerando pacote de gráficos para UHE Belo Monte...
# [*] Gerando pacote de gráficos para UHE Pimental...
# [*] Concluído! 8 Gráficos segregados foram exibidos na tela e salvos na pasta 'produtos'.
